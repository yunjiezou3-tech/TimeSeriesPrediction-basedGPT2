# %% [markdown]
# To run the test results directly, set the parameter “test_dir” to the folder containing the checkpoint files and comment out the lines `exp.train()` and `exp.test(setting, test=1)`.

# %% [markdown]
# ### Yearly

# %%
import os
import random
import numpy as np
import torch
from exp.exp_in_context_forecasting import Exp_In_Context_Forecast
from utils.tools import dotdict

fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args = dotdict()
args.task_name = 'in_context_forecast'
args.root_path = './dataset/m4/'
args.model_id = 'm4_Yearly'
args.model = 'AutoTimes_Gpt2'
args.test_data_path = 'm3_yearly_dataset.tsf'
args.data = 'm4'
args.is_training = 1
args.features = 'M'
args.seq_len = 18  # length of input（train） series
args.label_len = 12  # length of prefix of decoder（decoder 用的前缀长度）
args.token_len = 6  # 模型每次预测长度（AutoTimes 的预测是 token_len 为窗口的多步滚动预测）
args.test_seq_len = 6
args.test_label_len = 0
args.test_pred_len = 6  # test_pred_len 可能不是 token_len 的整数倍 → 需要多轮推理
args.batch_size = 16
args.learning_rate = 0.0005
args.mlp_hidden_layers = 2
args.train_epochs = 10
args.use_amp = False
args.cosine = False
args.tmax = 10
args.mix_embeds = False
args.drop_last = False
args.drop_short = False
args.checkpoints = './checkpoints/'
args.val_set_shuffle = True
args.seasonal_patterns = 'Yearly'
args.dropout = 0.1
args.llm_ckp_dir = './gpt2'
args.mlp_hidden_dim = 128
args.mlp_activation = 'tanh'
args.num_workers = 10
args.patience = 3
args.des = 'test'
args.loss = 'SMAPE'
args.lradj = 'type1'
args.weight_decay = 0
args.test_file_name = 'checkpoint.pth'
args.gpu = 0
args.visualize = True
args.test_dir = 'in_context_forecast_m4_Yearly_AutoTimes_Gpt2_m4_sl18_ll12_tl6_lr0.0005_bt16_wd0_hd128_hl2_cosTrue_mixFalse_Exp_0'
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# ...

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
exp = Exp_In_Context_Forecast(args)
# setting record of experiments
setting = '{}_{}_{}_sl{}_ll{}_tl{}_lr{}_bt{}_wd{}_hd{}_hl{}_cos{}_mix{}_{}'.format(
    args.task_name,
    args.model_id,
    args.model,
    args.data,
    args.seq_len,
    args.label_len,
    args.token_len,
    args.learning_rate,
    args.batch_size,
    args.weight_decay,
    args.mlp_hidden_dim,
    args.mlp_hidden_layers,
    args.cosine,
    args.mix_embeds,
    args.des)
# print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
# exp.train(setting)
print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
exp.test(setting, test=1)
torch.cuda.empty_cache()
# Out:
# cuda:0
# use mlp as tokenizer and detokenizer
# >>>>>>>testing : in_context_forecast_m4_Yearly_AutoTimes_Gpt2_slm4_ll18_tl12_lr6_bt0.0005_wd16_hd0_hl128_cos2_mixFalse_False<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# loading model from ./checkpoints/in_context_forecast_m4_Yearly_AutoTimes_Gpt2_m4_sl18_ll12_tl6_lr0.0005_bt16_wd0_hd128_hl2_cosTrue_mixFalse_Exp_0/checkpoint.pth
# 6 0 6
# test 645
# test 327
# zero shot forecasting
# test shape: (645, 6, 1) (645, 6, 1)
# mape:26.038622, smape:25.0972
# in context forecasting
# test shape: (327, 6, 1) (327, 6, 1)
# mape:21.623291, smape:17.3410
# Plotting comparison graphs...
# Comparison plot saved to ./checkpoints/in_context_forecast_m4_Yearly_AutoTimes_Gpt2_m4_sl18_ll12_tl6_lr0.0005_bt16_wd0_hd128_hl2_cosTrue_mixFalse_Exp_0/forecasting_comparison.png

# %% [markdown]
# ### Monthly

# %%
import os
import random
import numpy as np
import torch
from exp.exp_in_context_forecasting import Exp_In_Context_Forecast
from utils.tools import dotdict

fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args = dotdict()
args.task_name = 'in_context_forecast'
args.root_path = './dataset/m4/'
args.model_id = 'm4_Monthly'
args.model = 'AutoTimes_Gpt2'
args.test_data_path = 'm3_monthly_dataset.tsf'
args.data = 'm4'
args.is_training = 1
args.features = 'M'
args.seq_len = 54  # length of input（train） series
args.label_len = 36  # length of prefix of decoder（decoder 用的前缀长度）
args.token_len = 18  # 模型每次预测长度（AutoTimes 的预测是 token_len 为窗口的多步滚动预测）
args.test_seq_len = 18
args.test_label_len = 0
args.test_pred_len = 18  # test_pred_len 可能不是 token_len 的整数倍 → 需要多轮推理
args.batch_size = 16
args.learning_rate = 0.0005
args.mlp_hidden_layers = 2
args.train_epochs = 10
args.use_amp = False
args.cosine = False
args.tmax = 10
args.mix_embeds = False
args.drop_last = False
args.drop_short = False
args.checkpoints = './checkpoints/'
args.val_set_shuffle = True
args.seasonal_patterns = 'Monthly'
args.dropout = 0.1
args.llm_ckp_dir = './gpt2'
args.mlp_hidden_dim = 256
args.mlp_activation = 'tanh'
args.num_workers = 10
args.patience = 3
args.des = 'test'
args.loss = 'SMAPE'
args.lradj = 'type1'
args.weight_decay = 0
args.test_file_name = 'checkpoint.pth'
args.gpu = 0
args.visualize = True
args.test_dir = 'in_context_forecast_m4_Monthly_AutoTimes_Gpt2_m4_sl54_ll36_tl18_lr0.0005_bt16_wd0_hd256_hl2_cosTrue_mixFalse_Exp_0'
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# ...

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
exp = Exp_In_Context_Forecast(args)
# setting record of experiments
setting = '{}_{}_{}_sl{}_ll{}_tl{}_lr{}_bt{}_wd{}_hd{}_hl{}_cos{}_mix{}_{}'.format(
    args.task_name,
    args.model_id,
    args.model,
    args.data,
    args.seq_len,
    args.label_len,
    args.token_len,
    args.learning_rate,
    args.batch_size,
    args.weight_decay,
    args.mlp_hidden_dim,
    args.mlp_hidden_layers,
    args.cosine,
    args.mix_embeds,
    args.des)
# print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
# exp.train(setting)
print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
exp.test(setting, test=1)
torch.cuda.empty_cache()
# Out:
# cuda:0
# use mlp as tokenizer and detokenizer
# >>>>>>>testing : in_context_forecast_m4_Monthly_AutoTimes_Gpt2_slm4_ll54_tl36_lr18_bt0.0005_wd16_hd0_hl256_cos2_mixFalse_False<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# loading model from ./checkpoints/in_context_forecast_m4_Monthly_AutoTimes_Gpt2_m4_sl54_ll36_tl18_lr0.0005_bt16_wd0_hd256_hl2_cosTrue_mixFalse_Exp_0/checkpoint.pth
# 18 0 18
# test 1428
# test 1093
# zero shot forecasting
# test shape: (1428, 18, 1) (1428, 18, 1)
# mape:18.933876, smape:15.1599
# in context forecasting
# test shape: (1093, 18, 1) (1093, 18, 1)
# mape:17.943964, smape:12.3638
# Plotting comparison graphs...
# Comparison plot saved to ./checkpoints/in_context_forecast_m4_Monthly_AutoTimes_Gpt2_m4_sl54_ll36_tl18_lr0.0005_bt16_wd0_hd256_hl2_cosTrue_mixFalse_Exp_0/forecasting_comparison.png

# %% [markdown]
# ### Quarterly

# %%
import os
import random
import numpy as np
import torch
from exp.exp_in_context_forecasting import Exp_In_Context_Forecast
from utils.tools import dotdict

fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args = dotdict()
args.task_name = 'in_context_forecast'
args.root_path = './dataset/m4/'
args.model_id = 'm4_Quarterly'
args.model = 'AutoTimes_Gpt2'
args.test_data_path = 'm3_quarterly_dataset.tsf'
args.data = 'm4'
args.is_training = 1
args.features = 'M'
args.seq_len = 24  # length of input（train） series
args.label_len = 16  # length of prefix of decoder（decoder 用的前缀长度）
args.token_len = 8  # 模型每次预测长度（AutoTimes 的预测是 token_len 为窗口的多步滚动预测）
args.test_seq_len = 8
args.test_label_len = 0
args.test_pred_len = 8  # test_pred_len 可能不是 token_len 的整数倍 → 需要多轮推理
args.batch_size = 16
args.learning_rate = 0.0001
args.mlp_hidden_layers = 2
args.train_epochs = 10
args.use_amp = False
args.cosine = False
args.tmax = 10
args.mix_embeds = False
args.drop_last = False
args.drop_short = False
args.checkpoints = './checkpoints/'
args.val_set_shuffle = True
args.seasonal_patterns = 'Quarterly'
args.dropout = 0.1
args.llm_ckp_dir = './gpt2'
args.mlp_hidden_dim = 1024
args.mlp_activation = 'tanh'
args.num_workers = 10
args.patience = 3
args.des = 'test'
args.loss = 'SMAPE'
args.lradj = 'type1'
args.weight_decay = 0
args.test_file_name = 'checkpoint.pth'
args.gpu = 0
args.visualize = True
args.test_dir = 'in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0001_bt16_wd0_hd1024_hl2_cosTrue_mixFalse_Exp_0'
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# ...

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
exp = Exp_In_Context_Forecast(args)
# setting record of experiments
setting = '{}_{}_{}_sl{}_ll{}_tl{}_lr{}_bt{}_wd{}_hd{}_hl{}_cos{}_mix{}_{}'.format(
    args.task_name,
    args.model_id,
    args.model,
    args.data,
    args.seq_len,
    args.label_len,
    args.token_len,
    args.learning_rate,
    args.batch_size,
    args.weight_decay,
    args.mlp_hidden_dim,
    args.mlp_hidden_layers,
    args.cosine,
    args.mix_embeds,
    args.des)
# print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
# exp.train(setting)
print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
exp.test(setting, test=1)
torch.cuda.empty_cache()
# Out:
# cuda:0
# use mlp as tokenizer and detokenizer
# >>>>>>>testing : in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_slm4_ll24_tl16_lr8_bt0.0001_wd16_hd0_hl1024_cos2_mixFalse_False<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# loading model from ./checkpoints/in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0001_bt16_wd0_hd1024_hl2_cosTrue_mixFalse_Exp_0/checkpoint.pth
# 8 0 8
# test 756
# test 702
# zero shot forecasting
# test shape: (756, 8, 1) (756, 8, 1)
# mape:14.077712, smape:11.7071
# in context forecasting
# test shape: (702, 8, 1) (702, 8, 1)
# mape:13.914855, smape:10.6765
# Plotting comparison graphs...
# Comparison plot saved to ./checkpoints/in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0001_bt16_wd0_hd1024_hl2_cosTrue_mixFalse_Exp_0/forecasting_comparison.png

# %% [markdown]
# ### Others

# %%
import os
import random
import numpy as np
import torch
from exp.exp_in_context_forecasting import Exp_In_Context_Forecast
from utils.tools import dotdict

fix_seed = 2021
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

args = dotdict()
args.task_name = 'in_context_forecast'
args.root_path = './dataset/m4/'
args.model_id = 'm4_Quarterly'
args.model = 'AutoTimes_Gpt2'
args.test_data_path = 'm3_other_dataset.tsf'
args.data = 'm4'
args.is_training = 1
args.features = 'M'
args.seq_len = 24  # length of input（train） series
args.label_len = 16  # length of prefix of decoder（decoder 用的前缀长度）
args.token_len = 8  # 模型每次预测长度（AutoTimes 的预测是 token_len 为窗口的多步滚动预测）
args.test_seq_len = 8
args.test_label_len = 0
args.test_pred_len = 8  # test_pred_len 可能不是 token_len 的整数倍 → 需要多轮推理
args.batch_size = 16
args.learning_rate = 0.0005
args.mlp_hidden_layers = 2
args.train_epochs = 10
args.use_amp = False
args.cosine = False
args.tmax = 10
args.mix_embeds = False
args.drop_last = False
args.drop_short = False
args.checkpoints = './checkpoints/'
args.val_set_shuffle = True
args.seasonal_patterns = 'Quarterly'
args.dropout = 0.1
args.llm_ckp_dir = './gpt2'
args.mlp_hidden_dim = 512
args.mlp_activation = 'tanh'
args.num_workers = 10
args.patience = 3
args.des = 'test'
args.loss = 'SMAPE'
args.lradj = 'type1'
args.weight_decay = 0
args.test_file_name = 'checkpoint.pth'
args.gpu = 0
args.visualize = True
args.test_dir = 'in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0005_bt16_wd0_hd512_hl2_cosTrue_mixFalse_Exp_0'
print('Args in experiment:')
print(args)
# Out:
# Args in experiment:
# ...

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
exp = Exp_In_Context_Forecast(args)
# setting record of experiments
setting = '{}_{}_{}_sl{}_ll{}_tl{}_lr{}_bt{}_wd{}_hd{}_hl{}_cos{}_mix{}_{}'.format(
    args.task_name,
    args.model_id,
    args.model,
    args.data,
    args.seq_len,
    args.label_len,
    args.token_len,
    args.learning_rate,
    args.batch_size,
    args.weight_decay,
    args.mlp_hidden_dim,
    args.mlp_hidden_layers,
    args.cosine,
    args.mix_embeds,
    args.des)
# print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
# exp.train(setting)
print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
exp.test(setting, test=1)
torch.cuda.empty_cache()
# Out:
# cuda:0
# use mlp as tokenizer and detokenizer
# >>>>>>>testing : in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_slm4_ll24_tl16_lr8_bt0.0005_wd16_hd0_hl512_cos2_mixFalse_False<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# loading model from ./checkpoints/in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0005_bt16_wd0_hd512_hl2_cosTrue_mixFalse_Exp_0/checkpoint.pth
# 8 0 8
# test 174
# test 174
# zero shot forecasting
# test shape: (174, 8, 1) (174, 8, 1)
# mape:9.163446, smape:8.3240
# in context forecasting
# test shape: (174, 8, 1) (174, 8, 1)
# mape:5.939114, smape:5.1049
# Plotting comparison graphs...
# Comparison plot saved to ./checkpoints/in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0005_bt16_wd0_hd512_hl2_cosTrue_mixFalse_Exp_0/forecasting_comparison.png

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
img = Image.open('/root/AutoTimes-main/checkpoints/in_context_forecast_m4_Quarterly_AutoTimes_Gpt2_m4_sl24_ll16_tl8_lr0.0005_bt16_wd0_hd512_hl2_cosTrue_mixFalse_Exp_0/forecasting_comparison.png')
# plt.get_fignums()
# 使用matplotlib显示图片
plt.imshow(img)
plt.axis('off')
plt.show()
